# %%
import pandas as pd

# %%
data = pd.read_csv (r'C:\Users\salom\OneDrive\Área de Trabalho\NOAA Station Cities\data\ncei.noaa.gov_pub_data_ghcn_daily_ghcnd-stations.txt', error_bad_lines=False)

data.to_csv (r'C:\Users\salom\OneDrive\Área de Trabalho\NOAA Station Cities\data\data.csv', index=None)
# Out:
# C:\Users\salom\AppData\Local\Temp\ipykernel_260\834555014.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv (r'C:\Users\salom\OneDrive\Área de Trabalho\NOAA Station Cities\data\ncei.noaa.gov_pub_data_ghcn_daily_ghcnd-stations.txt', error_bad_lines=False)
# Skipping line 114: expected 1 fields, saw 2
# Skipping line 134: expected 1 fields, saw 2
# Skipping line 136: expected 1 fields, saw 2
# Skipping line 142: expected 1 fields, saw 2
# Skipping line 148: expected 1 fields, saw 2
# Skipping line 177: expected 1 fields, saw 2
# Skipping line 211: expected 1 fields, saw 2
# Skipping line 4686: expected 1 fields, saw 2
# Skipping line 20576: expected 1 fields, saw 2
# Skipping line 27758: expected 1 fields, saw 2
# Skipping line 28407: expected 1 fields, saw 2
# Skipping line 30944: expected 1 fields, saw 2
# Skipping line 31522: expected 1 fields, saw 2
# ...
